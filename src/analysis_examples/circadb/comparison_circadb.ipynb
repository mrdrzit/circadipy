# %%
## IMPORT LIBRARIES ----------------------------------------------------------------------------------------------------

# %matplotlib qt

# %reload_ext autoreload
# %autoreload 3

import matplotlib.pyplot as plt                                                                                         # Import matplotlib.pyplot to plot figures
import tkinter as tk                                                                                                    # Import TK to open folder dialogs to select folders
from tkinter import filedialog                                                                                          # Import filedialog to open folder dialogs to select folders
import numpy                                                                                                            # Import numpy to work with arrays and make calculations
from datetime import datetime, timedelta                                                                                # Import time to measure time 
import time                                                                                                             # Import time to measure time
import os                                                                                                               # Import path to work with paths
import pandas                                                                                                           # Import pandas to work with dataframes
import warnings                                                                                                         # Import warnings to ignore warnings
warnings.filterwarnings('ignore')                                                                                       # Ignore warnings

## IMPORT CIRCADIPY ----------------------------------------------------------------------------------------------------

import chrono_reader as chr                                                                                             # Import chrono_reader to read data
import chrono_plotter as chp                                                                                            # Import chrono_plotter to plot data
import chrono_rithm as chrt                                                                                             # Import chrono_rithm to make calculations
import chrono_simulation as chs                                                                                         # Import chrono_simulation to simulate data

# %%
## SET THE ENVIRONMENT -------------------------------------------------------------------------------------------------

root = tk.Tk()                                                                                                          # Create the root window
root.attributes('-topmost',True)                                                                                        # Keep the window on top of others
root.iconify()                                                                                                          # Hide the root window

database_files = filedialog.askopenfilenames(title='Select the database file(s)')                                       # Ask the user to select the database file(s)

main_save_folders = [os.path.dirname(file) for file in database_files]                                                  # Get the folder where the database file is located
root.destroy()                                                                                                          # Destroy the root window

for folder in main_save_folders:                                                                                        # For each folder
    print('The database file is located in: ' + folder)                                                                 # Print the folder where the database file is located
# Out:
# The database file is located in: E:/github/circadipy/src/comparison_study/circadb
# The database file is located in: E:/github/circadipy/src/comparison_study/circadb

# %%
## READ THE DATABASE ---------------------------------------------------------------------------------------------------

database = {}                                                                                                           # Create a dictionary with the database
save_folders = {}                                                                                                        # Create a dictionary with the save folder

for file in database_files:
    test = file.split('/')[-1].split('_')[-1]                                                                           # Get the parameter name from the file name
    test = test.split('.')[0]                                                                                           # Remove the extension from the file name
    print('Getting data from: ' + test)                                                                                 # Print the parameter name
    database[test] = {}                                                                                                 # Create a dictionary for the parameter

    if test == 'jtk':
        prefix = 'JTK'
    elif test == 'lomb':
        prefix = 'LombScargle_'

    main_save_folder = os.path.dirname(file)
    save_folders[test] = main_save_folder + '/' + test + '/'                                                             # Create a folder to save the plots

    # check if the folder exists
    if not os.path.exists(save_folders[test]):
        os.makedirs(save_folders[test])
    else:
        print('The folder already exists')

    database_df = pandas.read_csv(file)                                                                                 # Read the database file
    display(database_df.head())                                                                                         # Display the database

    # Only periods beteween 20 and 28 hours
    database_df = database_df[(database_df[prefix + 'period'] >= 20) & (database_df[prefix + 'period'] <= 28)]

    for row in database_df.iterrows():
        database[test][row[0]] = {}
        for column in database_df.columns:
            if column == 'Time':
                split_time = row[1][column].split(';')
                database[test][row[0]][column] = [int(i) for i in split_time]
            elif column == 'Values':
                split_values = row[1][column].split(';')
                database[test][row[0]][column] = [float(i) for i in split_values]
            else: 
                database[test][row[0]][column] = row[1][column]
# Out:
# Getting data from: jtk
# The folder already exists
#    Probeset_ID   Symbol                                               Time  \
# 0     10556463    Arntl  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 1     10487040     Fbn1  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 2     10518781     Per3  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 3     10433219    Nat15  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 4     10363773  Rhobtb1  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
#
#                                               Values          JTKP  \
# 0  167.8;360.7;350.3;428.6;380.1;268.8;152.3;89.5...  5.511650e-12
# 1  445.5;621.5;666.8;710.1;773.4;854.8;810.0;689....  1.256660e-11
# 2  339.6;199.2;162.6;153.4;176.1;223.4;322.7;516....  1.256660e-11
# 3  1292.6;1167.5;1082.6;1026.7;998.5;886.5;999.9;...  2.770380e-11
# 4  1101.3;1048.6;841.1;576.2;667.9;564.3;1014.2;1...  1.229230e-10
#
#            JTKQ  JTKperiod  JTKphase Tissue
# 0  1.489390e-07       24.0       0.0  heart
# 1  1.489390e-07       24.0       3.0  heart
# 2  1.489390e-07       24.0      12.0  heart
# 3  2.462590e-07       26.0      17.0  heart
# 4  8.741310e-07       24.0      13.0  heart
# Getting data from: lomb
# The folder already exists
#    Probeset_ID   Symbol                                               Time  \
# 0     10522467  Rasl11b  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 1     10553092      Dbp  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 2     10356601     Per2  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 3     10350733    Rgs16  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
# 4     10449741     Sik1  18;20;22;24;26;28;30;32;34;36;38;40;42;44;46;4...
#
#                                               Values  LombScargle_P  \
# 0  116.5;117.3;146.4;215.8;205.6;223.5;191.9;214....       0.000837
# 1  197.2;239.5;231.3;249.7;280.9;311.7;318.2;341....       0.000988
# 2  144.4;145.4;149.5;143.4;165.9;197.2;215.8;271....       0.001150
# 3  434.7;857.4;881.5;1187.6;1041.1;1336.1;1221.0;...       0.001300
# 4  184.0;201.4;214.4;278.9;294.9;269.4;273.2;320....       0.001480
#
#    LombScargle_Q  LombScargle_period  LombScargle_phase    Tissue
# 0            1.0              23.892               3.75  scn_2014
# 1            1.0              23.892               7.03  scn_2014
# 2            1.0              23.892               9.81  scn_2014
# 3            1.0              23.892               3.70  scn_2014
# 4            1.0              23.064               3.77  scn_2014

# %%
## CREATE A GENERIC ASC TO CIRCADIPY -----------------------------------------------------------------------------------

# Set a generic date with the format MM/DD/YY,HH:MM:SS
generic_date = '01/01/20,00:00:00'
generic_date = datetime.strptime(generic_date, '%m/%d/%y,%H:%M:%S')

# Set the generic time with the format HH:MM:SS with the times (in hours) in the database
for test in database:
    for id in database[test]:     
        database[test][id]['circadipy'] = [generic_date + timedelta(hours=t) for t in database[test][id]['Time']]
        database[test][id]['circadipy'] = [datetime.strftime(t, '%m/%d/%y,%H:%M:%S') for t in database[test][id]['circadipy']]
        database[test][id]['circadipy'] = [t + ',' + str(v) for t, v in zip(database[test][id]['circadipy'], database[test][id]['Values'])]
        file_name = str(database[test][id]['Probeset_ID']) + '_' + str(database[test][id]['Symbol']) + '.asc'
        file_to_save = os.path.join(save_folders[test], file_name)
        database[test][id]['file_name'] = file_to_save
        # with open(file_to_save, 'w') as f:
        #     f.write('\n'.join(database[test][id]['circadipy']))
        # f.close()

# %%
## CONFIGURE THE EXPERIMENT --------------------------------------------------------------------------------------------

zt_0_time = 0                                                                                                           # Set the time for the first ZT (0)
type = 'generic'                                                                                                        # Set the type of the data decoding (endocrino or intellicage)
labels_dict = {'cycle_types': ['LD'], 'test_labels': ['Gene'], 'cycle_days': []}                                        # Create a dictionary to store to pass as argument to the read_protocol function

## READ THE PROTOCOL ---------------------------------------------------------------------------------------------------

for test in database:
    for id in database[test]:     
        file = database[test][id]['file_name']
        name = str(database[test][id]['Probeset_ID']) + '_' + str(database[test][id]['Symbol'])
        database[test][id]['protocol'] = chr.read_protocol(name, file, zt_0_time = zt_0_time, labels_dict = labels_dict, 
                                                            type = type, consider_first_day = True)                     # Read the protocol (chrono_reader.py)
        database[test][id]['protocol'].normalize_data(type = 'minmax', per_day = False)                                 # Normalize the data (chrono_reader.py)
        database[test][id]['protocol'].apply_filter(window = 3, type = 'moving_average', order = 2, reverse = False)    # Apply a filter to the data (chrono_reader.py)

# %%
## SET THE PARAMETERS FOR THE COSINOR FITTING --------------------------------------------------------------------------

dict = {'time_shape': 'continuous',                     
        'step': 0.01, 
        'start_time': 20, 
        'end_time': 28, 
        'n_components': [1]}                                                                                            # Create a dictionary to pass as argument to the fit_cosinor function

## FIT THE COSINOR TO THE DATA -----------------------------------------------------------------------------------------

init = time.time()                                                                                                      # Get the initial time

for test in database:
    for id in database[test]:     
        save_folder = save_folders[test]                                                                                # Create a folder to save the results
        protocol = database[test][id]['protocol']
        best_models, _ = chrt.fit_cosinor(protocol, dict = dict, save_folder = save_folder)                             # Fit the cosinor to the data (chrono_rithm.py)
        database[test][id]['best_models'] = best_models
        chp.model_over_signal(protocol, best_models, position = 'head', mv_avg_window = 1, save_folder = save_folder,
                              format = 'svg')                                                                           # Plot representative figure with the data and the respective model (using chrono_plotter.py)

end = time.time() - init                                                                                                # Get the time elapsed

# %%
## COMPARE THE COSINOR FITTING WITH THE GORUND-TRUTH PERIODS -----------------------------------------------------------

for test in database:
    period_error = []                                                                                                   # Create an empty list to store the model error
    phase_error = []                                                                                                    # Create an empty list to store the model error
    p_error = []                                                                                                        # Create an empty list to store the model error
    
    for id in database[test]:     
        if id != 'save_folder':
            if test == 'jtk':
                prefix = 'JTK'
                plot_name = 'JTK'
            elif test == 'lomb':
                prefix = 'LombScargle_'
                plot_name = 'Lomb-Scargle'
            
            name = database[test][id]['Symbol']

            period_circadipy = database[test][id]['best_models']['period'][0]                                           # Get the activity period calculated by the model
            period_other = database[test][id][prefix + 'period']                                                        # Get the activity period used to generate the data
            
            phase_circadipy = database[test][id]['best_models']['acrophase_zt'][0]                                      # Get the activity phase calculated by the model
            phase_other = database[test][id][prefix + 'phase']                                                          # Get the activity phase used to generate the data
            
            phase_circadipy = phase_circadipy - 6
            if phase_circadipy < 0:
                phase_circadipy += 24
            if phase_other < 0:
                phase_other += 24
            if phase_circadipy < 12 and phase_other > 12:
                phase_circadipy += 24            

            period_error.append(period_circadipy - period_other)                                                        # Calculate the model error for the period
            phase_error.append(phase_circadipy - phase_other)                                                           # Calculate the model error for the phase

            if phase_error[-1] > 12:
                phase_circadipy -= period_circadipy
                phase_error[-1] = phase_circadipy - phase_other
            elif phase_error[-1] < -12:
                phase_other -= period_other
                phase_error[-1] = phase_circadipy - phase_other

            print('------------------------------------------------------------------')
            print('Gene: ' + str(name) + ' (' + test + ')')                                                             # Print the gene name
            print('CircadiPy: ' + str(period_circadipy) + ' Other: ' + str(period_other))                               # Print the period calculated by the model and the ground-truth period
            print('The period error for ' + str(id) + ' is: ' + str(period_error[-1]))                                  # Print the model error for the period
            print('CircadiPy: ' + str(phase_circadipy) + ' Other: ' + str(phase_other))                                 # Print the phase calculated by the model and the ground-truth phase
            print('The phase error for ' + str(id) + ' is: ' + str(phase_error[-1]))                                    # Print the model error for the phase

    period_error = numpy.array(period_error)                                                                            # Convert the list to a numpy array
    phase_error = numpy.array(phase_error)                                                                              # Convert the list to a numpy array
    
    mean_period_error = numpy.mean(period_error)                                                                        # Calculate the mean error for the period
    mean_phase_error = numpy.mean(phase_error)                                                                          # Calculate the mean error for the phase

    std_period_error = numpy.std(period_error)                                                                          # Calculate the standard deviation for the period
    std_phase_error = numpy.std(phase_error)                                                                            # Calculate the standard deviation for the phase

    print('------------------------------------------------------------------')
    print('The mean error for the period is: ' + str(mean_period_error) + ' +/- ' + str(std_period_error))              # Print the mean error for the period
    print('The mean error for the phase is: ' + str(mean_phase_error) + ' +/- ' + str(std_phase_error))                 # Print the mean error for the phase

    fig = plt.figure(figsize=(6, 3))
    fig.suptitle('Parametrization Error (CircadiPy - ' + plot_name + ')', fontsize=16)
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.hist(period_error, bins=16, color='midnightblue', edgecolor='midnightblue')
    ax1.set_title('PERIOD\nMEAN: ' + str(round(mean_period_error,2)) + ' +/- ' + str(round(std_period_error,2)), fontsize=16)
    ax1.set_xlabel('PERIOD (HOUR)', fontsize=16)
    ax1.set_ylabel('FREQUENCY', fontsize=16)
    ax1.set_xlim(-3.5, 3.5)
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.hist(phase_error, bins=16, color='midnightblue', edgecolor='midnightblue')
    ax2.set_title('PHASE\nMEAN: ' + str(round(mean_phase_error,2)) + ' +/- ' + str(round(std_phase_error,2)), fontsize=16)
    ax2.set_xlabel('PHASE (HOUR)', fontsize=16)
    ax2.set_xlim(-3.5, 3.5)
    plt.tight_layout()
    
    plt.savefig(save_folders[test] + 'parametrization_error_' + test + '.svg', dpi=300)
# Out:
# ------------------------------------------------------------------
# Gene: Arntl (jtk)
# CircadiPy: 23.610000000000564 Other: 24.0
# The period error for 0 is: -0.3899999999994357
# CircadiPy: -0.0324624624628953 Other: 0.0
# The phase error for 0 is: -0.0324624624628953
# ------------------------------------------------------------------
# Gene: Fbn1 (jtk)
# CircadiPy: 23.290000000000514 Other: 24.0
# The period error for 1 is: -0.7099999999994857
# CircadiPy: 2.998938938939137 Other: 3.0
# The phase error for 1 is: -0.001061061060863011
# ------------------------------------------------------------------
# Gene: Per3 (jtk)
# CircadiPy: 23.240000000000506 Other: 24.0
# The period error for 2 is: -0.7599999999994935
# CircadiPy: 11.26134134134172 Other: 12.0
# The phase error for 2 is: -0.7386586586582808
# ------------------------------------------------------------------
# Gene: Nat15 (jtk)
# CircadiPy: 24.99000000000078 Other: 26.0
# The period error for 3 is: -1.00999999999922
# CircadiPy: 16.413453453454153 Other: 17.0
# The phase error for 3 is: -0.586546546545847
# ------------------------------------------------------------------
# Gene: Rhobtb1 (jtk)
# CircadiPy: 23.550000000000555 Other: 24.0
# The period error for 4 is: -0.44999999999944507
# CircadiPy: 12.811711711712157 Other: 13.0
# The phase error for 4 is: -0.18828828828784339
# ------------------------------------------------------------------
# Gene: Per2 (jtk)
# CircadiPy: 23.72000000000058 Other: 24.0
# The period error for 5 is: -0.2799999999994185
# CircadiPy: 12.377657657658105 Other: 13.0
# The phase error for 5 is: -0.622342342341895
# ------------------------------------------------------------------
# Gene: Rasgrp3 (jtk)
# CircadiPy: 25.450000000000852 Other: 26.0
# The period error for 6 is: -0.5499999999991481
# CircadiPy: 23.095095095095267 Other: 23.0
# The phase error for 6 is: 0.09509509509526737
# ------------------------------------------------------------------
# Gene: Timp3 (jtk)
# CircadiPy: 22.990000000000467 Other: 23.0
# The period error for 7 is: -0.009999999999532605
# CircadiPy: 13.146826826827215 Other: 14.0
# The phase error for 7 is: -0.8531731731727845
# ------------------------------------------------------------------
# Gene: Tef (jtk)
# CircadiPy: 23.410000000000533 Other: 24.0
# The period error for 8 is: -0.589999999999467
# CircadiPy: 12.606146146146564 Other: 13.0
# The phase error for 8 is: -0.39385385385343596
# ------------------------------------------------------------------
# Gene: Nr1d1 (jtk)
# CircadiPy: 23.490000000000546 Other: 24.0
# The period error for 9 is: -0.5099999999994544
# CircadiPy: 6.9324324324327335 Other: 7.0
# The phase error for 9 is: -0.06756756756726645
# ------------------------------------------------------------------
# Gene: Spon2 (jtk)
# CircadiPy: 22.460000000000385 Other: 22.0
# The period error for 10 is: 0.46000000000038455
# CircadiPy: 1.3742542542543799 Other: 2.0
# The phase error for 10 is: -0.6257457457456201
# ------------------------------------------------------------------
# Gene: Fmo2 (jtk)
# CircadiPy: 23.670000000000574 Other: 24.0
# The period error for 11 is: -0.3299999999994263
# CircadiPy: 14.708288288288788 Other: 15.0
# The phase error for 11 is: -0.291711711711212
# ------------------------------------------------------------------
# Gene: Rcan1 (jtk)
# CircadiPy: 24.050000000000633 Other: 24.0
# The period error for 12 is: 0.050000000000633094
# CircadiPy: -1.0907407407412428 Other: 0.0
# The phase error for 12 is: -1.0907407407412428
# ------------------------------------------------------------------
# Gene: Ypel2 (jtk)
# CircadiPy: 24.34000000000068 Other: 24.0
# The period error for 13 is: 0.3400000000006784
# CircadiPy: 20.582622622622694 Other: 21.0
# The phase error for 13 is: -0.4173773773773064
# ------------------------------------------------------------------
# Gene: Nr1d2 (jtk)
# CircadiPy: 23.27000000000051 Other: 24.0
# The period error for 14 is: -0.7299999999994888
# CircadiPy: 10.305305305305662 Other: 11.0
# The phase error for 14 is: -0.6946946946943378
# ------------------------------------------------------------------
# Gene: Slc41a3 (jtk)
# CircadiPy: 23.680000000000575 Other: 24.0
# The period error for 15 is: -0.31999999999942474
# CircadiPy: 1.3007407407409168 Other: 2.0
# The phase error for 15 is: -0.6992592592590832
# ------------------------------------------------------------------
# Gene: Adam19 (jtk)
# CircadiPy: 23.880000000000607 Other: 24.0
# The period error for 16 is: -0.11999999999939348
# CircadiPy: 22.589549549549666 Other: 23.0
# The phase error for 16 is: -0.4104504504503339
# ------------------------------------------------------------------
# Gene: Clock (jtk)
# CircadiPy: 23.39000000000053 Other: 24.0
# The period error for 17 is: -0.6099999999994701
# CircadiPy: 0.5089289289290768 Other: 0.0
# The phase error for 17 is: 0.5089289289290768
# ------------------------------------------------------------------
# Gene: Fabp7 (jtk)
# CircadiPy: 23.560000000000556 Other: 24.0
# The period error for 18 is: -0.4399999999994435
# CircadiPy: 2.8202602602604685 Other: 3.0
# The phase error for 18 is: -0.1797397397395315
# ------------------------------------------------------------------
# Gene: Kdr (jtk)
# CircadiPy: 23.530000000000552 Other: 24.0
# The period error for 19 is: -0.4699999999994482
# CircadiPy: 0.7834234234235815 Other: 1.0
# The phase error for 19 is: -0.2165765765764185
# ------------------------------------------------------------------
# Gene: Tcap (jtk)
# CircadiPy: 23.690000000000577 Other: 24.0
# The period error for 20 is: -0.3099999999994232
# CircadiPy: 9.745905905906287 Other: 10.0
# The phase error for 20 is: -0.25409409409371264
# ------------------------------------------------------------------
# Gene: Angptl7 (jtk)
# CircadiPy: 24.300000000000672 Other: 24.0
# The period error for 21 is: 0.3000000000006722
# CircadiPy: 16.037837837838453 Other: 17.0
# The phase error for 21 is: -0.9621621621615475
# ------------------------------------------------------------------
# Gene: Slc46a3 (jtk)
# CircadiPy: 23.06000000000048 Other: 24.0
# The period error for 22 is: -0.9399999999995217
# CircadiPy: 15.144104104104542 Other: 16.0
# The phase error for 22 is: -0.8558958958954577
# ------------------------------------------------------------------
# Gene: Gm4956 (jtk)
# CircadiPy: 21.73000000000027 Other: 22.0
# The period error for 23 is: -0.26999999999972957
# CircadiPy: 14.098618618618872 Other: 15.0
# The phase error for 23 is: -0.9013813813811282
# ------------------------------------------------------------------
# Gene: Tmem171 (jtk)
# CircadiPy: 23.550000000000555 Other: 24.0
# The period error for 24 is: -0.44999999999944507
# CircadiPy: 22.148948948949048 Other: 22.0
# The phase error for 24 is: 0.1489489489490481
# ------------------------------------------------------------------
# Gene: nan (jtk)
# CircadiPy: 23.930000000000614 Other: 24.0
# The period error for 25 is: -0.06999999999938566
# CircadiPy: 22.024264264264364 Other: 22.0
# The phase error for 25 is: 0.02426426426436379
# ------------------------------------------------------------------
# Gene: Hlf (jtk)
# CircadiPy: 23.26000000000051 Other: 24.0
# The period error for 26 is: -0.7399999999994904
# CircadiPy: 12.021261261261657 Other: 12.0
# The phase error for 26 is: 0.021261261261656728
# ------------------------------------------------------------------
# Gene: Tead1 (jtk)
# CircadiPy: 25.140000000000803 Other: 25.0
# The period error for 27 is: 0.14000000000080348
# CircadiPy: 20.717837837837923 Other: 21.0
# The phase error for 27 is: -0.2821621621620771
# ------------------------------------------------------------------
# Gene: Tspan4 (jtk)
# CircadiPy: 23.470000000000542 Other: 24.0
# The period error for 28 is: -0.5299999999994576
# CircadiPy: 11.009289289289683 Other: 11.5
# The phase error for 28 is: -0.49071071071031724
# ------------------------------------------------------------------
# Gene: Colq (jtk)
# CircadiPy: 23.310000000000517 Other: 24.0
# The period error for 29 is: -0.6899999999994826
# CircadiPy: 0.11333333333347184 Other: 0.0
# The phase error for 29 is: 0.11333333333347184
# ------------------------------------------------------------------
# Gene: Fam161b (jtk)
# CircadiPy: 23.170000000000496 Other: 24.0
# The period error for 30 is: -0.8299999999995045
# CircadiPy: 18.139159159159163 Other: 18.0
# The phase error for 30 is: 0.13915915915916344
# ------------------------------------------------------------------
# Gene: Rorc (jtk)
# CircadiPy: 24.380000000000685 Other: 25.0
# The period error for 31 is: -0.6199999999993153
# CircadiPy: 19.269029029029067 Other: 19.0
# The phase error for 31 is: 0.2690290290290669
# ------------------------------------------------------------------
# Gene: Tspan18 (jtk)
# CircadiPy: 24.260000000000666 Other: 24.0
# The period error for 32 is: 0.2600000000006659
# CircadiPy: 0.16820820820837667 Other: 0.0
# The phase error for 32 is: 0.16820820820837667
# ------------------------------------------------------------------
# Gene: Npas2 (jtk)
# CircadiPy: 23.430000000000536 Other: 24.0
# The period error for 33 is: -0.5699999999994638
# CircadiPy: 0.47315315315330153 Other: 0.0
# The phase error for 33 is: 0.47315315315330153
# ------------------------------------------------------------------
# Gene: Dbp (jtk)
# CircadiPy: 23.050000000000477 Other: 24.0
# The period error for 34 is: -0.9499999999995232
# CircadiPy: 10.151151151151481 Other: 10.5
# The phase error for 34 is: -0.34884884884851886
# ------------------------------------------------------------------
# Gene: Pik3r1 (jtk)
# CircadiPy: 24.130000000000646 Other: 24.0
# The period error for 35 is: 0.1300000000006456
# CircadiPy: 14.434414414414963 Other: 15.0
# The phase error for 35 is: -0.5655855855850369
# ------------------------------------------------------------------
# Gene: Mid1ip1 (jtk)
# CircadiPy: 23.690000000000577 Other: 24.0
# The period error for 36 is: -0.3099999999994232
# CircadiPy: 13.919519519520005 Other: 15.0
# The phase error for 36 is: -1.080480480479995
# ------------------------------------------------------------------
# Gene: Fgf13 (jtk)
# CircadiPy: 24.170000000000652 Other: 24.0
# The period error for 37 is: 0.17000000000065185
# CircadiPy: 10.597217217217665 Other: 11.0
# The phase error for 37 is: -0.40278278278233515
# ------------------------------------------------------------------
# Gene: Tead1 (jtk)
# CircadiPy: 24.92000000000077 Other: 25.0
# The period error for 38 is: -0.07999999999923091
# CircadiPy: 20.74394394394403 Other: 21.0
# The phase error for 38 is: -0.2560560560559715
# ------------------------------------------------------------------
# Gene: Podn (jtk)
# CircadiPy: 24.09000000000064 Other: 24.0
# The period error for 39 is: 0.09000000000063935
# CircadiPy: 15.027507507508062 Other: 16.0
# The phase error for 39 is: -0.9724924924919378
# ------------------------------------------------------------------
# Gene: Foxj2 (jtk)
# CircadiPy: 23.660000000000572 Other: 24.0
# The period error for 40 is: -0.33999999999942787
# CircadiPy: -0.40222222222266524 Other: 0.0
# The phase error for 40 is: -0.40222222222266524
# ------------------------------------------------------------------
# Gene: 9030425E11Rik (jtk)
# CircadiPy: 24.22000000000066 Other: 24.0
# The period error for 41 is: 0.22000000000065967
# CircadiPy: 0.9823423423425304 Other: 2.0
# The phase error for 41 is: -1.0176576576574696
# ------------------------------------------------------------------
# Gene: Akap1 (jtk)
# CircadiPy: 24.28000000000067 Other: 24.0
# The period error for 42 is: 0.28000000000066905
# CircadiPy: 23.006686686686823 Other: 23.5
# The phase error for 42 is: -0.49331331331317685
# ------------------------------------------------------------------
# Gene: Fbln2 (jtk)
# CircadiPy: 27.99000000000125 Other: 28.0
# The period error for 43 is: -0.009999999998751008
# CircadiPy: 18.655855855856956 Other: 19.0
# The phase error for 43 is: -0.3441441441430442
# ------------------------------------------------------------------
# Gene: F830001A07Rik (jtk)
# CircadiPy: 22.5700000000004 Other: 24.0
# The period error for 44 is: -1.4299999999995983
# CircadiPy: 13.791111111111466 Other: 14.0
# The phase error for 44 is: -0.2088888888885343
# ------------------------------------------------------------------
# Gene: Itgb6 (jtk)
# CircadiPy: 24.400000000000688 Other: 25.0
# The period error for 45 is: -0.5999999999993122
# CircadiPy: -0.440440440440959 Other: 0.5
# The phase error for 45 is: -0.940440440440959
# ------------------------------------------------------------------
# Gene: Cd93 (jtk)
# CircadiPy: 23.980000000000622 Other: 24.0
# The period error for 46 is: -0.01999999999937785
# CircadiPy: 0.19303303303319197 Other: 0.0
# The phase error for 46 is: 0.19303303303319197
# ------------------------------------------------------------------
# Gene: Col15a1 (jtk)
# CircadiPy: 21.810000000000283 Other: 22.0
# The period error for 47 is: -0.18999999999971706
# CircadiPy: 3.8679879879881174 Other: 5.0
# The phase error for 47 is: -1.1320120120118826
# ------------------------------------------------------------------
# Gene: Aqp1 (jtk)
# CircadiPy: 25.57000000000087 Other: 26.0
# The period error for 48 is: -0.4299999999991293
# CircadiPy: 16.37055055055131 Other: 17.0
# The phase error for 48 is: -0.6294494494486891
# ------------------------------------------------------------------
# Gene: Cntfr (jtk)
# CircadiPy: 25.56000000000087 Other: 28.0
# The period error for 49 is: -2.439999999999131
# CircadiPy: 15.850090090090834 Other: 16.0
# The phase error for 49 is: -0.14990990990916586
# ------------------------------------------------------------------
# The mean error for the period is: -0.3731999999993987 +/- 0.4975517661510305
# The mean error for the phase is: -0.3729305305302767 +/- 0.4199535980345815
# ------------------------------------------------------------------
# Gene: Rasl11b (lomb)
# CircadiPy: 23.97000000000062 Other: 23.892
# The period error for 0 is: 0.07800000000062113
# CircadiPy: 4.125465465465728 Other: 3.75
# The phase error for 0 is: 0.37546546546572834
# ------------------------------------------------------------------
# Gene: Dbp (lomb)
# CircadiPy: 23.920000000000613 Other: 23.892
# The period error for 1 is: 0.028000000000613312
# CircadiPy: 7.45649649649684 Other: 7.03
# The phase error for 1 is: 0.4264964964968394
# ------------------------------------------------------------------
# Gene: Per2 (lomb)
# CircadiPy: 24.460000000000697 Other: 23.892
# The period error for 2 is: 0.5680000000006977
# CircadiPy: 9.425225225225665 Other: 9.81
# The phase error for 2 is: -0.3847747747743355
# ------------------------------------------------------------------
# Gene: Rgs16 (lomb)
# CircadiPy: 23.78000000000059 Other: 23.892
# The period error for 3 is: -0.11199999999940857
# CircadiPy: 3.9975975975978475 Other: 3.7
# The phase error for 3 is: 0.2975975975978473
# ------------------------------------------------------------------
# Gene: Sik1 (lomb)
# CircadiPy: 23.370000000000527 Other: 23.064
# The period error for 4 is: 0.30600000000052674
# CircadiPy: 4.62060060060084 Other: 3.77
# The phase error for 4 is: 0.8506006006008398
# ------------------------------------------------------------------
# Gene: Nr1d1 (lomb)
# CircadiPy: 23.940000000000616 Other: 23.892
# The period error for 5 is: 0.04800000000061644
# CircadiPy: 3.969009009009266 Other: 3.73
# The phase error for 5 is: 0.23900900900926603
# ------------------------------------------------------------------
# Gene: Rbm33 (lomb)
# CircadiPy: 24.910000000000768 Other: 24.783
# The period error for 6 is: 0.12700000000076628
# CircadiPy: 2.6274874874877554 Other: 3.85
# The phase error for 6 is: -1.2225125125122447
# ------------------------------------------------------------------
# Gene: Fbxl21 (lomb)
# CircadiPy: 24.04000000000063 Other: 23.892
# The period error for 7 is: 0.14800000000063207
# CircadiPy: 6.465185185185513 Other: 5.78
# The phase error for 7 is: 0.6851851851855129
# ------------------------------------------------------------------
# Gene: Il22 (lomb)
# CircadiPy: 24.440000000000694 Other: 24.783
# The period error for 8 is: -0.3429999999993072
# CircadiPy: 18.68500500500502 Other: 19.0
# The phase error for 8 is: -0.3149949949949793
# ------------------------------------------------------------------
# Gene: Ifit3 (lomb)
# CircadiPy: 22.840000000000444 Other: 23.064
# The period error for 9 is: -0.2239999999995561
# CircadiPy: 14.07359359359398 Other: 15.27
# The phase error for 9 is: -1.1964064064060196
# ------------------------------------------------------------------
# Gene: Fabp7 (lomb)
# CircadiPy: 24.510000000000705 Other: 23.892
# The period error for 10 is: 0.6180000000007055
# CircadiPy: 3.22498498498525 Other: 3.72
# The phase error for 10 is: -0.4950150150147503
# ------------------------------------------------------------------
# Gene: Rcan1 (lomb)
# CircadiPy: 24.520000000000707 Other: 24.783
# The period error for 11 is: -0.2629999999992947
# CircadiPy: 4.112352352352643 Other: 3.85
# The phase error for 11 is: 0.26235235235264254
# ------------------------------------------------------------------
# Gene: Hmgb3 (lomb)
# CircadiPy: 23.690000000000577 Other: 23.892
# The period error for 12 is: -0.20199999999942264
# CircadiPy: 7.943663663664003 Other: 9.23
# The phase error for 12 is: -1.2863363363359976
# ------------------------------------------------------------------
# Gene: Il22 (lomb)
# CircadiPy: 24.61000000000072 Other: 24.783
# The period error for 13 is: -0.17299999999928062
# CircadiPy: 18.394154154154165 Other: 18.61
# The phase error for 13 is: -0.2158458458458341
# ------------------------------------------------------------------
# Gene: Odc1 (lomb)
# CircadiPy: 24.73000000000074 Other: 24.783
# The period error for 14 is: -0.05299999999926186
# CircadiPy: 4.4960160160163305 Other: 4.44
# The phase error for 14 is: 0.056016016016330106
# ------------------------------------------------------------------
# Gene: Hspa2 (lomb)
# CircadiPy: 21.85000000000029 Other: 22.291
# The period error for 15 is: -0.4409999999997112
# CircadiPy: 18.74364364364365 Other: 16.01
# The phase error for 15 is: 2.7336436436436493
# ------------------------------------------------------------------
# Gene: Tsc22d3 (lomb)
# CircadiPy: 23.51000000000055 Other: 23.064
# The period error for 16 is: 0.4460000000005486
# CircadiPy: 13.956436436436903 Other: 15.28
# The phase error for 16 is: -1.3235635635630967
# ------------------------------------------------------------------
# Gene: Chrna3 (lomb)
# CircadiPy: 24.590000000000718 Other: 24.783
# The period error for 17 is: -0.19299999999928374
# CircadiPy: 6.947287287287667 Other: 6.71
# The phase error for 17 is: 0.2372872872876668
# ------------------------------------------------------------------
# Gene: Slc2a13 (lomb)
# CircadiPy: 23.430000000000536 Other: 23.064
# The period error for 18 is: 0.3660000000005361
# CircadiPy: 7.227747747748049 Other: 6.82
# The phase error for 18 is: 0.4077477477480489
# ------------------------------------------------------------------
# Gene: Nfil3 (lomb)
# CircadiPy: 22.840000000000444 Other: 23.064
# The period error for 20 is: -0.2239999999995561
# CircadiPy: 20.240560560560606 Other: 18.57
# The phase error for 20 is: 1.670560560560606
# ------------------------------------------------------------------
# Gene: Gm129 (lomb)
# CircadiPy: 23.64000000000057 Other: 23.892
# The period error for 21 is: -0.25199999999943046
# CircadiPy: 6.967687687687999 Other: 6.69
# The phase error for 21 is: 0.27768768768799834
# ------------------------------------------------------------------
# Gene: Mt1 (lomb)
# CircadiPy: 24.520000000000707 Other: 23.892
# The period error for 22 is: 0.6280000000007071
# CircadiPy: 11.770250250250765 Other: 10.76
# The phase error for 22 is: 1.010250250250765
# ------------------------------------------------------------------
# Gene: Pde10a (lomb)
# CircadiPy: 24.940000000000772 Other: 24.783
# The period error for 23 is: 0.15700000000077097
# CircadiPy: 3.6864064064067072 Other: 3.9
# The phase error for 23 is: -0.21359359359329266
# ------------------------------------------------------------------
# Gene: Mettl7a1 (lomb)
# CircadiPy: 21.940000000000303 Other: 22.291
# The period error for 24 is: -0.3509999999996971
# CircadiPy: 18.878478478478495 Other: 16.03
# The phase error for 24 is: 2.8484784784784942
# ------------------------------------------------------------------
# Gene: C030019I05Rik (lomb)
# CircadiPy: 26.07000000000095 Other: 25.742
# The period error for 25 is: 0.328000000000948
# CircadiPy: 4.647207207207595 Other: 4.51
# The phase error for 25 is: 0.13720720720759516
# ------------------------------------------------------------------
# Gene: Zim1 (lomb)
# CircadiPy: 24.080000000000638 Other: 23.892
# The period error for 26 is: 0.18800000000063832
# CircadiPy: 2.870310310310545 Other: 3.62
# The phase error for 26 is: -0.7496896896894549
# ------------------------------------------------------------------
# Gene: Nr1d2 (lomb)
# CircadiPy: 21.620000000000253 Other: 21.568
# The period error for 27 is: 0.052000000000251845
# CircadiPy: 7.504384384384544 Other: 6.79
# The phase error for 27 is: 0.7143843843845437
# ------------------------------------------------------------------
# Gene: Epha6 (lomb)
# CircadiPy: 26.28000000000098 Other: 25.742
# The period error for 28 is: 0.5380000000009808
# CircadiPy: 20.84108108108119 Other: 22.5
# The phase error for 28 is: -1.6589189189188112
# ------------------------------------------------------------------
# Gene: Tanc2 (lomb)
# CircadiPy: 24.890000000000764 Other: 24.783
# The period error for 29 is: 0.10700000000076315
# CircadiPy: 2.9693693693696446 Other: 3.61
# The phase error for 29 is: -0.6406306306303553
# ------------------------------------------------------------------
# Gene: Hspa1a (lomb)
# CircadiPy: 22.76000000000043 Other: 23.064
# The period error for 30 is: -0.3039999999995686
# CircadiPy: 18.36452452452453 Other: 16.11
# The phase error for 30 is: 2.2545245245245304
# ------------------------------------------------------------------
# Gene: Creb3l1 (lomb)
# CircadiPy: 24.79000000000075 Other: 24.783
# The period error for 31 is: 0.007000000000747519
# CircadiPy: 5.712592592592946 Other: 5.49
# The phase error for 31 is: 0.22259259259294595
# ------------------------------------------------------------------
# Gene: Dusp4 (lomb)
# CircadiPy: 23.150000000000492 Other: 23.064
# The period error for 32 is: 0.08600000000049235
# CircadiPy: 5.864664664664916 Other: 5.46
# The phase error for 32 is: 0.40466466466491635
# ------------------------------------------------------------------
# Gene: Hmgb3 (lomb)
# CircadiPy: 23.39000000000053 Other: 23.064
# The period error for 33 is: 0.32600000000052987
# CircadiPy: 7.767087087087399 Other: 9.04
# The phase error for 33 is: -1.2729129129126004
# ------------------------------------------------------------------
# Gene: Hsph1 (lomb)
# CircadiPy: 24.060000000000635 Other: 23.892
# The period error for 34 is: 0.1680000000006352
# CircadiPy: 22.046126126126232 Other: 21.95
# The phase error for 34 is: 0.09612612612623295
# ------------------------------------------------------------------
# Gene: I830012O16Rik (lomb)
# CircadiPy: 22.480000000000388 Other: 22.291
# The period error for 35 is: 0.1890000000003873
# CircadiPy: 14.657297297297653 Other: 15.24
# The phase error for 35 is: -0.5827027027023473
# ------------------------------------------------------------------
# Gene: Stip1 (lomb)
# CircadiPy: 23.470000000000542 Other: 23.064
# The period error for 36 is: 0.40600000000054237
# CircadiPy: 21.85293293293302 Other: 21.6
# The phase error for 36 is: 0.25293293293301744
# ------------------------------------------------------------------
# Gene: Chordc1 (lomb)
# CircadiPy: 23.560000000000556 Other: 23.892
# The period error for 37 is: -0.33199999999944296
# CircadiPy: 19.36784784784788 Other: 17.65
# The phase error for 37 is: 1.7178478478478816
# ------------------------------------------------------------------
# Gene: Acr (lomb)
# CircadiPy: 24.570000000000714 Other: 24.783
# The period error for 38 is: -0.21299999999928687
# CircadiPy: 5.756216216216558 Other: 5.5
# The phase error for 38 is: 0.25621621621655777
# ------------------------------------------------------------------
# Gene: Nat2 (lomb)
# CircadiPy: 25.010000000000783 Other: 24.783
# The period error for 39 is: 0.2270000000007819
# CircadiPy: 14.078098098098728 Other: 15.35
# The phase error for 39 is: -1.2719019019012716
# ------------------------------------------------------------------
# Gene: nan (lomb)
# CircadiPy: 22.850000000000446 Other: 22.291
# The period error for 40 is: 0.5590000000004451
# CircadiPy: 25.04484484484498 Other: 22.96
# The phase error for 40 is: 2.08484484484498
# ------------------------------------------------------------------
# Gene: Scn3b (lomb)
# CircadiPy: 24.35000000000068 Other: 23.892
# The period error for 41 is: 0.45800000000068053
# CircadiPy: 0.824824824825015 Other: 2.05
# The phase error for 41 is: -1.2251751751749849
# ------------------------------------------------------------------
# Gene: Fn3k (lomb)
# CircadiPy: 25.94000000000093 Other: 25.742
# The period error for 42 is: 0.19800000000092766
# CircadiPy: 20.59659659659669 Other: 22.21
# The phase error for 42 is: -1.6134034034033107
# ------------------------------------------------------------------
# Gene: Mmp14 (lomb)
# CircadiPy: 25.920000000000925 Other: 25.742
# The period error for 43 is: 0.17800000000092453
# CircadiPy: 22.047567567567715 Other: 23.32
# The phase error for 43 is: -1.2724324324322858
# ------------------------------------------------------------------
# Gene: Usp36 (lomb)
# CircadiPy: 24.04000000000063 Other: 23.892
# The period error for 44 is: 0.14800000000063207
# CircadiPy: 6.465185185185513 Other: 5.81
# The phase error for 44 is: 0.6551851851855135
# ------------------------------------------------------------------
# Gene: nan (lomb)
# CircadiPy: 24.42000000000069 Other: 23.892
# The period error for 45 is: 0.5280000000006915
# CircadiPy: 0.9422222222224157 Other: 1.86
# The phase error for 45 is: -0.9177777777775844
# ------------------------------------------------------------------
# Gene: 0610007P22Rik (lomb)
# CircadiPy: 27.99000000000125 Other: 27.902
# The period error for 46 is: 0.08800000000124797
# CircadiPy: 10.306486486487216 Other: 10.03
# The phase error for 46 is: 0.27648648648721696
# ------------------------------------------------------------------
# Gene: Per1 (lomb)
# CircadiPy: 25.96000000000093 Other: 25.742
# The period error for 47 is: 0.21800000000093078
# CircadiPy: 5.277917917918325 Other: 4.89
# The phase error for 47 is: 0.3879179179183252
# ------------------------------------------------------------------
# Gene: Cys1 (lomb)
# CircadiPy: 23.59000000000056 Other: 23.892
# The period error for 48 is: -0.3019999999994383
# CircadiPy: 14.213253253253733 Other: 14.3
# The phase error for 48 is: -0.08674674674626814
# ------------------------------------------------------------------
# Gene: Rbm3 (lomb)
# CircadiPy: 23.13000000000049 Other: 23.064
# The period error for 49 is: 0.06600000000048922
# CircadiPy: 9.744144144144478 Other: 10.07
# The phase error for 49 is: -0.32585585585552224
# ------------------------------------------------------------------
# The mean error for the period is: 0.09385714285778496 +/- 0.28893011654192363
# The mean error for the phase is: 0.07281873710471724 +/- 1.0689264338124238
